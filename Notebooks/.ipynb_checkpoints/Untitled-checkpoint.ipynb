# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import scipy.stats as stats
from config import uid, pwd, database, server
engine = create_engine(f"postgresql://{uid}:{pwd}@{server}/{database}")
conn = engine.connect()

# %%
df = pd.DataFrame(engine.execute("SELECT * FROM clean").fetchall())
df.head()
# Out:
#    0   1       2            3    4    5      6                      7    8   \
# 0   0  63    Male  Non-Anginal  145  233   True                 Normal  150
# 1   1  37    Male     Atypical  130  250  False  ST-T Wave Abnormality  187
# 2   2  41  Female      Typical  130  204  False                 Normal  172
# 3   3  56    Male      Typical  120  236  False  ST-T Wave Abnormality  178
# 4   4  57  Female            0  120  354  False  ST-T Wave Abnormality  163
#
#     9    10       11  12            13      14
# 0   No  2.3  Missing   0        Normal  Normal
# 1   No  3.5  Missing   0  Fixed Defect  Normal
# 2   No  1.4     Flat   0  Fixed Defect  Normal
# 3   No  0.8     Flat   0  Fixed Defect  Normal
# 4  Yes  0.6     Flat   0  Fixed Defect  Normal
